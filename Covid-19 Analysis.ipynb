# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("covid_19_clean_complete.csv")

# %%
data
# Out:
#       Province/State         Country/Region        Lat       Long        Date  \
# 0                NaN            Afghanistan  33.939110  67.709953  2020-01-22
# 1                NaN                Albania  41.153300  20.168300  2020-01-22
# 2                NaN                Algeria  28.033900   1.659600  2020-01-22
# 3                NaN                Andorra  42.506300   1.521800  2020-01-22
# 4                NaN                 Angola -11.202700  17.873900  2020-01-22
# ...              ...                    ...        ...        ...         ...
# 49063            NaN  Sao Tome and Principe   0.186400   6.613100  2020-07-27
# 49064            NaN                  Yemen  15.552727  48.516388  2020-07-27
# 49065            NaN                Comoros -11.645500  43.333300  2020-07-27
# 49066            NaN             Tajikistan  38.861000  71.276100  2020-07-27
# 49067            NaN                Lesotho -29.610000  28.233600  2020-07-27
#
# ...

# %%
data.count()
# Out:
# Province/State    14664
# Country/Region    49068
# Lat               49068
# Long              49068
# Date              49068
# Confirmed         49068
# Deaths            49068
# Recovered         49068
# Active            49068
# WHO Region        49068
# dtype: int64

# %%
data.isnull()
# Out:
#        Province/State  Country/Region    Lat   Long   Date  Confirmed  Deaths  \
# 0                True           False  False  False  False      False   False
# 1                True           False  False  False  False      False   False
# 2                True           False  False  False  False      False   False
# 3                True           False  False  False  False      False   False
# 4                True           False  False  False  False      False   False
# ...               ...             ...    ...    ...    ...        ...     ...
# 49063            True           False  False  False  False      False   False
# 49064            True           False  False  False  False      False   False
# 49065            True           False  False  False  False      False   False
# 49066            True           False  False  False  False      False   False
# 49067            True           False  False  False  False      False   False
#
# ...

# %%
data.isnull().sum()
# Out:
# Province/State    34404
# Country/Region        0
# Lat                   0
# Long                  0
# Date                  0
# Confirmed             0
# Deaths                0
# Recovered             0
# Active                0
# WHO Region            0
# dtype: int64

# %%
sns.heatmap(data.isnull())
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # The number of confirmed, deaths and recovered cases in each region.

# %% [markdown]
# whenever there is 'each' we use groupby function

# %%
data.head(2)
# Out:
#   Province/State Country/Region       Lat       Long        Date  Confirmed  \
# 0            NaN    Afghanistan  33.93911  67.709953  2020-01-22          0
# 1            NaN        Albania  41.15330  20.168300  2020-01-22          0
#
#    Deaths  Recovered  Active             WHO Region
# 0       0          0       0  Eastern Mediterranean
# 1       0          0       0                 Europe

# %%
data.groupby('Country/Region')

# %%
data.groupby('Country/Region').sum()
# Out:
#                             Lat          Long  Confirmed  Deaths  Recovered  \
# Country/Region
# Afghanistan         6380.552680  12729.471164    1936390   49098     798240
# Albania             7736.820400   3791.640400     196702    5708     118877
# Algeria             5270.373200    312.004800    1179755   77972     755897
# Andorra             7991.184400    286.098400      94404    5423      69074
# Angola             -2106.107600   3360.293200      22662    1078       6573
# ...                         ...           ...        ...     ...        ...
# West Bank and Gaza  6007.013600   6623.841600     233461    1370      61124
# Western Sahara      4552.514000  -2422.530400        901      63        648
# Yemen               2923.912676   9121.080944      67180   17707      23779
# Zambia             -2469.172636   5235.674416     129421    2643      83611
# Zimbabwe           -3574.902344   5481.113116      50794     881      12207
#
#                      Active
# ...

# %%
data.groupby('Country/Region').sum().head(20)
# Out:
#                              Lat           Long  Confirmed  Deaths  Recovered  \
# Country/Region
# Afghanistan           6380.55268   12729.471164    1936390   49098     798240
# Albania               7736.82040    3791.640400     196702    5708     118877
# Algeria               5270.37320     312.004800    1179755   77972     755897
# Andorra               7991.18440     286.098400      94404    5423      69074
# Angola               -2106.10760    3360.293200      22662    1078       6573
# Antigua and Barbuda   3207.43040  -11617.723200       4487     326       2600
# Argentina            -7222.22680  -11959.939600    4450658   97749    1680024
# Armenia               7532.99080    8467.181600    1587173   27089     857482
# Australia           -48287.83760  212598.653200     960247   11387     711928
# Austria               8933.04560    2735.418800    2034986   71390    1638380
# Azerbaijan            7546.90280    8944.457200    1134717   14282     703402
# ...

# %%
data.groupby('Country/Region')['Confirmed'].sum()
# Out:
# Country/Region
# Afghanistan           1936390
# Albania                196702
# Algeria               1179755
# Andorra                 94404
# Angola                  22662
#                        ...
# West Bank and Gaza     233461
# Western Sahara            901
# Yemen                   67180
# Zambia                 129421
# Zimbabwe                50794
# Name: Confirmed, Length: 187, dtype: int64

# %%
data.groupby('Country/Region')['Confirmed'].sum().sort_values(ascending = True)
# Out:
# Country/Region
# Western Sahara                 901
# Papua New Guinea              1185
# Holy See                      1356
# Greenland                     1507
# Saint Kitts and Nevis         1772
#                            ...
# Spain                     27404045
# India                     40883464
# Russia                    45408411
# Brazil                    89524967
# US                       224345948
# Name: Confirmed, Length: 187, dtype: int64

# %%
data.groupby('Country/Region')['Confirmed'].sum().sort_values(ascending = False).head(10)
# Out:
# Country/Region
# US                224345948
# Brazil             89524967
# Russia             45408411
# India              40883464
# Spain              27404045
# United Kingdom     26748587
# Italy              26745145
# France             21210926
# Germany            21059152
# Iran               19339267
# Name: Confirmed, dtype: int64

# %%
 data.groupby('Country/Region')['Confirmed','Recovered'].sum()
# Out:
# C:\Users\WELCOME\AppData\Local\Temp\ipykernel_10740\15951759.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby('Country/Region')['Confirmed','Recovered'].sum()
#                     Confirmed  Recovered
# Country/Region
# Afghanistan           1936390     798240
# Albania                196702     118877
# Algeria               1179755     755897
# Andorra                 94404      69074
# Angola                  22662       6573
# ...                       ...        ...
# West Bank and Gaza     233461      61124
# Western Sahara            901        648
# Yemen                   67180      23779
# Zambia                 129421      83611
# Zimbabwe                50794      12207
#
# [187 rows x 2 columns]

# %% [markdown]
# # Remove all the records where confirmed cases is Less than 10

# %%
data.head(2)
# Out:
#   Province/State Country/Region       Lat       Long        Date  Confirmed  \
# 0            NaN    Afghanistan  33.93911  67.709953  2020-01-22          0
# 1            NaN        Albania  41.15330  20.168300  2020-01-22          0
#
#    Deaths  Recovered  Active             WHO Region
# 0       0          0       0  Eastern Mediterranean
# 1       0          0       0                 Europe

# %%
data.Confirmed < 10
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 49063    False
# 49064    False
# 49065    False
# 49066    False
# 49067    False
# Name: Confirmed, Length: 49068, dtype: bool

# %%
data[data.Confirmed < 10]
# Out:
#                   Province/State  Country/Region       Lat        Long  \
# 0                            NaN     Afghanistan  33.93911   67.709953
# 1                            NaN         Albania  41.15330   20.168300
# 2                            NaN         Algeria  28.03390    1.659600
# 3                            NaN         Andorra  42.50630    1.521800
# 4                            NaN          Angola -11.20270   17.873900
# ...                          ...             ...       ...         ...
# 48918           Saint Barthelemy          France  17.90000  -62.833300
# 49048      Northwest Territories          Canada  64.82550 -124.845700
# 49052                   Anguilla  United Kingdom  18.22060  -63.068600
# 49053     British Virgin Islands  United Kingdom  18.42070  -64.640000
# 49060  Saint Pierre and Miquelon          France  46.88520  -56.315900
#
#              Date  Confirmed  Deaths  Recovered  Active             WHO Region
# ...

# %% [markdown]
# Temporaray removal of data

# %%
data[~(data.Confirmed < 10)]
# Out:
#       Province/State         Country/Region        Lat        Long  \
# 49           Beijing                  China  40.182400  116.414200
# 53         Guangdong                  China  23.341700  113.424400
# 61             Hubei                  China  30.975600  112.270700
# 80          Zhejiang                  China  29.183200  120.093400
# 310          Beijing                  China  40.182400  116.414200
# ...              ...                    ...        ...         ...
# 49063            NaN  Sao Tome and Principe   0.186400    6.613100
# 49064            NaN                  Yemen  15.552727   48.516388
# 49065            NaN                Comoros -11.645500   43.333300
# 49066            NaN             Tajikistan  38.861000   71.276100
# 49067            NaN                Lesotho -29.610000   28.233600
#
#              Date  Confirmed  Deaths  Recovered  Active             WHO Region
# 49     2020-01-22         14       0          0      14        Western Pacific
# ...

# %% [markdown]
# Permanent removal of data

# %%
data = data[~(data.Confirmed < 10)]

# %%
data
# Out:
#       Province/State         Country/Region        Lat        Long  \
# 49           Beijing                  China  40.182400  116.414200
# 53         Guangdong                  China  23.341700  113.424400
# 61             Hubei                  China  30.975600  112.270700
# 80          Zhejiang                  China  29.183200  120.093400
# 310          Beijing                  China  40.182400  116.414200
# ...              ...                    ...        ...         ...
# 49063            NaN  Sao Tome and Principe   0.186400    6.613100
# 49064            NaN                  Yemen  15.552727   48.516388
# 49065            NaN                Comoros -11.645500   43.333300
# 49066            NaN             Tajikistan  38.861000   71.276100
# 49067            NaN                Lesotho -29.610000   28.233600
#
#              Date  Confirmed  Deaths  Recovered  Active             WHO Region
# 49     2020-01-22         14       0          0      14        Western Pacific
# ...

# %%
data.head(20)
# Out:
#     Province/State Country/Region      Lat      Long        Date  Confirmed  \
# 49         Beijing          China  40.1824  116.4142  2020-01-22         14
# 53       Guangdong          China  23.3417  113.4244  2020-01-22         26
# 61           Hubei          China  30.9756  112.2707  2020-01-22        444
# 80        Zhejiang          China  29.1832  120.0934  2020-01-22         10
# 310        Beijing          China  40.1824  116.4142  2020-01-23         22
# 314      Guangdong          China  23.3417  113.4244  2020-01-23         32
# 322          Hubei          China  30.9756  112.2707  2020-01-23        444
# 334       Shanghai          China  31.2020  121.4491  2020-01-23         16
# 341       Zhejiang          China  29.1832  120.0934  2020-01-23         27
# 570          Anhui          China  31.8257  117.2264  2020-01-24         15
# 571        Beijing          China  40.1824  116.4142  2020-01-24         36
# ...

# %% [markdown]
# # Region where the confirmed cases are maximum

# %%
data = pd.read_csv("covid_19_clean_complete.csv")

# %%
data
# Out:
#       Province/State         Country/Region        Lat       Long        Date  \
# 0                NaN            Afghanistan  33.939110  67.709953  2020-01-22
# 1                NaN                Albania  41.153300  20.168300  2020-01-22
# 2                NaN                Algeria  28.033900   1.659600  2020-01-22
# 3                NaN                Andorra  42.506300   1.521800  2020-01-22
# 4                NaN                 Angola -11.202700  17.873900  2020-01-22
# ...              ...                    ...        ...        ...         ...
# 49063            NaN  Sao Tome and Principe   0.186400   6.613100  2020-07-27
# 49064            NaN                  Yemen  15.552727  48.516388  2020-07-27
# 49065            NaN                Comoros -11.645500  43.333300  2020-07-27
# 49066            NaN             Tajikistan  38.861000  71.276100  2020-07-27
# 49067            NaN                Lesotho -29.610000  28.233600  2020-07-27
#
# ...

# %%
data.groupby('Country/Region')

# %%
data.groupby('Country/Region').Confirmed.sum()
# Out:
# Country/Region
# Afghanistan           1936390
# Albania                196702
# Algeria               1179755
# Andorra                 94404
# Angola                  22662
#                        ...
# West Bank and Gaza     233461
# Western Sahara            901
# Yemen                   67180
# Zambia                 129421
# Zimbabwe                50794
# Name: Confirmed, Length: 187, dtype: int64

# %%
data.groupby('Country/Region').Confirmed.sum().sort_values(ascending = False)
# Out:
# Country/Region
# US                       224345948
# Brazil                    89524967
# Russia                    45408411
# India                     40883464
# Spain                     27404045
#                            ...
# Saint Kitts and Nevis         1772
# Greenland                     1507
# Holy See                      1356
# Papua New Guinea              1185
# Western Sahara                 901
# Name: Confirmed, Length: 187, dtype: int64

# %%
 data.groupby('Country/Region').Confirmed.sum().sort_values(ascending = False).head(20)
# Out:
# Country/Region
# US                224345948
# Brazil             89524967
# Russia             45408411
# India              40883464
# Spain              27404045
# United Kingdom     26748587
# Italy              26745145
# France             21210926
# Germany            21059152
# Iran               19339267
# Peru               19263916
# Turkey             17903345
# Chile              16935654
# Mexico             14946202
# China              14132002
# Pakistan           12833994
# Saudi Arabia       12362961
# South Africa       11168743
# Canada              9356551
# Bangladesh          8754729
# Name: Confirmed, dtype: int64

# %% [markdown]
# # Region where minimum number of Deaths cases are recorded

# %%
data.groupby('Deaths')

# %%
data.groupby('Deaths').Deaths.sum()
# Out:
# Deaths
# 0              0
# 1           3235
# 2           3866
# 3           5577
# 4           3868
#            ...
# 144430    144430
# 145560    145560
# 146465    146465
# 146935    146935
# 148011    148011
# Name: Deaths, Length: 3640, dtype: int64

# %%
data.groupby('Deaths').Deaths.sum().sort_values(ascending = True)
# Out:
# Deaths
# 0              0
# 366          366
# 378          378
# 396          396
# 404          404
#            ...
# 146465    146465
# 146935    146935
# 148011    148011
# 27136     325632
# 4512      460224
# Name: Deaths, Length: 3640, dtype: int64

# %%
data.groupby('Deaths').Deaths.sum().sort_values(ascending = True).head(20)
# Out:
# Deaths
# 0        0
# 366    366
# 378    378
# 396    396
# 404    404
# 416    416
# 419    419
# 420    420
# 439    439
# 455    455
# 466    466
# 472    472
# 500    500
# 505    505
# 511    511
# 512    512
# 516    516
# 517    517
# 519    519
# 528    528
# Name: Deaths, dtype: int64

# %% [markdown]
# # sorting of the data wrt no. of confirmed cases in ascending order.

# %%
data.head(2)
# Out:
#   Province/State Country/Region       Lat       Long        Date  Confirmed  \
# 0            NaN    Afghanistan  33.93911  67.709953  2020-01-22          0
# 1            NaN        Albania  41.15330  20.168300  2020-01-22          0
#
#    Deaths  Recovered  Active             WHO Region
# 0       0          0       0  Eastern Mediterranean
# 1       0          0       0                 Europe

# %%
data.sort_values(by = ['Confirmed'], ascending = True).head(50)
# Out:
#                    Province/State         Country/Region        Lat  \
# 0                             NaN            Afghanistan  33.939110
# 8074                          NaN                  Burma  21.916200
# 8075                     Anguilla         United Kingdom  18.220600
# 8076       British Virgin Islands         United Kingdom  18.420700
# 8077     Turks and Caicos Islands         United Kingdom  21.694000
# 8078                          NaN               Botswana -22.328500
# 8079                          NaN                Burundi  -3.373100
# 8080                          NaN           Sierra Leone   8.460555
# 8081                          NaN                 Malawi -13.254300
# 8082  Falkland Islands (Malvinas)         United Kingdom -51.796300
# 8083    Saint Pierre and Miquelon                 France  46.885200
# 8084                          NaN            South Sudan   6.877000
# 8085                          NaN         Western Sahara  24.215500
# ...

# %% [markdown]
# # Sort the entire data wrt no. of recovered cases in descending order

# %%
data.head(3)
# Out:
#   Province/State Country/Region       Lat       Long        Date  Confirmed  \
# 0            NaN    Afghanistan  33.93911  67.709953  2020-01-22          0
# 1            NaN        Albania  41.15330  20.168300  2020-01-22          0
# 2            NaN        Algeria  28.03390   1.659600  2020-01-22          0
#
#    Deaths  Recovered  Active             WHO Region
# 0       0          0       0  Eastern Mediterranean
# 1       0          0       0                 Europe
# 2       0          0       0                 Africa

# %%
data.sort_values(by = ['Recovered'], ascending = False).head(50)
# Out:
#       Province/State Country/Region        Lat       Long        Date  \
# 48835            NaN         Brazil -14.235000  -51.92530  2020-07-27
# 48574            NaN         Brazil -14.235000  -51.92530  2020-07-26
# 48313            NaN         Brazil -14.235000  -51.92530  2020-07-25
# 48052            NaN         Brazil -14.235000  -51.92530  2020-07-24
# 47791            NaN         Brazil -14.235000  -51.92530  2020-07-23
# 47530            NaN         Brazil -14.235000  -51.92530  2020-07-22
# 47269            NaN         Brazil -14.235000  -51.92530  2020-07-21
# 47008            NaN         Brazil -14.235000  -51.92530  2020-07-20
# 46747            NaN         Brazil -14.235000  -51.92530  2020-07-19
# 46486            NaN         Brazil -14.235000  -51.92530  2020-07-18
# 46225            NaN         Brazil -14.235000  -51.92530  2020-07-17
# 45964            NaN         Brazil -14.235000  -51.92530  2020-07-16
# ...
